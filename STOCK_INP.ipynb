# %%
import pandas as pd

# %% [markdown]
# AGREGAR DESCARGA SAP

# %%
stock_inp = pd.read_excel("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Bases Transito (python)/STOCK_INP.XLSX",dtype={'Número de material externo largo':'str', 'Centro':'str','Almacén':'str'} )
stock_r3 = pd.read_excel("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Bases Transito (python)/STOCK_R3.XLSX")

# %%
stock_inp.rename(columns = {'Número de material externo largo':'Material'}, inplace=True)
stock_inp = stock_inp[['Material','Centro','Almacén']]

# %%
stock_final = pd.concat([stock_inp,stock_r3])

# %%
stock_final.tail()
# Out:
#          Material Centro Almacén Unidad medida base  Libre utilización Moneda  \
# 58688   ZYY211SF0  201.0  1100.0                 UN                2.0    CLP
# 58689  ZZJ110155B  201.0  1100.0                 UN               11.0    CLP
# 58690  ZZJ113250A  201.0  1100.0                 UN               27.0    CLP
# 58691   ZZJ118110  201.0  1100.0                 UN              204.0    CLP
# 58692         NaN    NaN     NaN                NaN                NaN    CLP
#
#        Valor libre util.  Trans./Trasl.  Val.trans.c/cond.  \
# 58688       2.685200e+05            0.0                0.0
# 58689       2.491400e+04            0.0                0.0
# 58690       8.828320e+05            0.0                0.0
# 58691       4.506940e+05            0.0                0.0
# 58692       1.588246e+11            NaN         19527578.0
#
#        Valor en insp.cal.  Stock no libre  Valor no libre  Bloqueado  \
# ...
